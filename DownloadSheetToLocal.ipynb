# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import gspread
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
credentials = GoogleCredentials.get_application_default()
gc = gspread.authorize(credentials)

# %%
sh = gc.open('Stock_List')
worksheet_list = sh.worksheets()
worksheet = worksheet_list[-1]
print(worksheet)
list_of_lists = worksheet.get_all_values()
stock_list = []
for list_ in list_of_lists:
    stock_list.append(list_[0])
print(stock_list)
print(len(stock_list))
# Out:
# <Worksheet 'Stock_List_V.2020-10-21' id:1461925057>
# ...

# %%
from google.colab import files

# %%
for stock in stock_list:
    # with open('/content/drive/My Drive/Stock_Prediction/StockHistoryPrice/' + str(stock), 'w') as f:
    files.download('/content/drive/My Drive/Stock_Prediction/StockHistoryPrice/' + str(stock) + '.gsheet')
